# %% [markdown]
# <a href="https://colab.research.google.com/github/akshathav25/Innomatics-research-lab/blob/main/Internship_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
stored_username = "admin"
stored_password = "1234"

username = input("Enter username: ")
password = input("Enter password: ")

if username == stored_username and password == stored_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful

# %%
marks = [45, 78, 90, 33, 60]

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 50:
        pass_count += 1
    else:
        fail_count += 1

print("Total Students:", len(marks))
print("Number of Students Passed:", pass_count)
print("Number of Students Failed:", fail_count)
# Out:
# Total Students: 5
# Number of Students Passed: 3
# Number of Students Failed: 2

# %%
names = [" Alice ", "bob", " CHARLIE "]

cleaned_names = []

for name in names:
    cleaned_name = name.strip().lower()
    cleaned_names.append(cleaned_name)

print("Cleaned Names:", cleaned_names)
# Out:
# Cleaned Names: ['alice', 'bob', 'charlie']

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

for message in messages:
    length = len(message)
    print("Message:", message)
    print("Length:", length)

    if length > 10:
        print("Status: Long Message (More than 10 characters)")
    else:
        print("Status: Short Message")

    print("-" * 30)
# Out:
# Message: Hi
# Length: 2
# Status: Short Message
# ------------------------------
# Message: Welcome to the platform
# Length: 23
# Status: Long Message (More than 10 characters)
# ------------------------------
# Message: OK
# Length: 2
# Status: Short Message
# ------------------------------

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

error_count = 0

for log in logs:
    if log == "ERROR":
        error_count += 1

print("Total ERROR entries:", error_count)
# Out:
# Total ERROR entries: 2
